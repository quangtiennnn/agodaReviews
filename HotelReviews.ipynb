# %%
from hotelreviewFunction import *
# Out:
# C:\Users\darkn\OneDrive\Máy tính\Hotel\AgodaReviewScraping\hotelreviewFunction.py:23: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   city = pd.read_csv('city.csv')

# %%
city.head().T
# Out:
#                                                                        0  \
# hotel_id                                                             163
# chain_id                                                               0
# chain_name                                                      No chain
# brand_id                                                               0
# brand_name                                                           NaN
# hotel_name                                           Ramana Saigon Hotel
# hotel_formerly_name                                          Amara Hotel
# hotel_translated_name                                Ramana Saigon Hotel
# addressline1                          323 Le Van Sy Street, District 3
# addressline2                                                         NaN
# zipcode
# city                                                    Ho Chi Minh City
# state                                                                NaN
# ...

# %%
hotelReviews('9195')
